# %% [markdown]
# # Tom's Data Onion
#
# **Author**: Abbas Moosajee
#
# **Website**: https://www.tomdalling.com/toms-data-onion/

# %%
import os, re, time, copy
start_time = time.time()

file_path = os.path.join(os.getcwd(), "payload.txt")
onion_payload = open(file_path, "rb").read().splitlines()

print(len(onion_payload))
# Out:
# 5381
